# %% [markdown]
# # 图像特征——harris
# ![](./images_for_note/feature/harris_1.png)
# ## 基本原理
# ![](./images_for_note/feature/harris_2.png)
#
# ![](./images_for_note/feature/harris_8.png)
#
# ![](./images_for_note/feature/harris_4.png)
#
# > M 矩阵为实对称阵，可以对角化
#
# ![](./images_for_note/feature/harris_5.png)
#
# > $\lambda_{min}, \lambda_{max}$为M的两个特征值
#
# ![](./images_for_note/feature/harris_6.png)
#
# ![](./images_for_note/feature/harris_7.png)
# > $\alpha$ 在opencv中一般比较小，为0.04左右
#
# **cv2.cornerHarris()**
# - img：数据类型是float32的输入图像
# - blockSize：角点检测中指定区域的大小
# - ksize：Sobel求导中使用的窗口大小(一般为3)
# - k：参数取值范围是[0.04, 0.06]

# %%
# 导入库
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
img = cv2.imread('./images_for_note/feature/chessboard.jpg')
print('img.shape', img.shape)
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
# gray = np.float32(gray)
# dst保存每个点的c值
dst = cv2.cornerHarris(gray, 2, 3, 0.04)
print('dst.shape', dst.shape)
plt.imshow(dst)
# Out:
# img.shape (512, 512, 3)
# dst.shape (512, 512)

# %%
img[dst>0.01*dst.max()] = [255, 0, 0]
plt.imshow(img)

# %%
img = cv2.imread('./images_for_note/feature/test_1.jpg')
print('img.shape', img.shape)
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
# gray = np.float32(gray)
# dst保存每个点的c值
dst = cv2.cornerHarris(gray, 2, 3, 0.04)
print('dst.shape', dst.shape)

img[dst>0.01*dst.max()] = [255, 0, 0]
plt.imshow(img)
# Out:
# img.shape (800, 1200, 3)
# dst.shape (800, 1200)
